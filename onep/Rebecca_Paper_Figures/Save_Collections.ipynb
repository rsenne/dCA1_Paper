# %%
import os
import onep

base_dir = '/Users/suthardr/Desktop'
mouse_ids = ['astroF3', 'astroF5', 'astroF6', 'astroF7', 'astroF8', 'astroF9', 'astroF10', 'astroF11',
             'astroM3', 'astroM4', 'astroM5', 'astroM6', 'astroM7', 'astroM8', 'astroM9', 'astroM10']
sessions = ['hab', 'fc', 'cxta', 'cxtb']

collection = []

for mouse_id in mouse_ids:
    for session in sessions:
        # Build the expected file path
        file_path = os.path.join(
            base_dir, 'Cell_Traces', f'{mouse_id}_traces', f'{mouse_id}_{session}_traces.csv'
        )
        if os.path.exists(file_path):
            try:
                obj = onep.InscopixProcessing(animal=mouse_id, session=session, data_directory=base_dir)
                collection.append(obj)
                print(f"Loaded: {mouse_id} - {session}")
            except Exception as e:
                print(f"Error loading {mouse_id} {session}: {e}")
        else:
            print(f"Missing file: {file_path}")

# %%
import pickle
from collections import defaultdict

session_groups = defaultdict(list)

for obj in collection:
    session_groups[obj.session].append(obj)

for session, mice in session_groups.items():
    group = onep.dCA1Group(*mice)
    group.preprocess()
    path = f"/Users/suthardr/Desktop/collection_{session}_allmice.pkl"
    with open(path, 'wb') as f:
        pickle.dump(group, f)
    print(f"Pickled group for {session}: {path}")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ...

# %%
#Initial submission
# astro_3 = onep.InscopixProcessing(session='ext1', animal='astro3', data_directory='/Users/suthardr/Desktop/')
#
# astro_4 = onep.InscopixProcessing(session='ext1', animal='astro4', data_directory='/Users/suthardr/Desktop/')
#
# # astro_5 = onep.InscopixProcessing(session='ext1', animal='astro5', data_directory='/Users/suthardr/Desktop/')
# #
# # astro_6 = onep.InscopixProcessing(session='ext1', animal='astro6', data_directory='/Users/suthardr/Desktop/')
#
# collection = onep.dCA1Group(astro_3, astro_4)
# collection.preprocess()

# %%
# astro_3 = onep.InscopixProcessing(session='ext1', animal='astro3', data_directory='/Users/suthardr/Desktop/')
#
# astro_4 = onep.InscopixProcessing(session='ext1', animal='astro4', data_directory='/Users/suthardr/Desktop/')
#
# # astro_5 = onep.InscopixProcessing(session='ext1', animal='astro5', data_directory='/Users/suthardr/Desktop/')
# #
# # astro_6 = onep.InscopixProcessing(session='ext1', animal='astro6', data_directory='/Users/suthardr/Desktop/')
#
# collection = onep.dCA1Group(astro_3, astro_4)
# collection.preprocess()

# %%
# import pickle
#
# # Specify the file path to save the pickle
# pickle_filepath = '/Users/suthardr/Desktop/collection_cxta_ext1.pkl'  # Change this to your desired path
#
# # Pickle the collection
# with open(pickle_filepath, 'wb') as file:
#     pickle.dump(collection, file)
#
# print(f'Collection has been pickled and saved to {pickle_filepath}')
# Out:
# Collection has been pickled and saved to /Users/suthardr/Desktop/collection_cxta_ext1.pkl

# %%
# astro_7 = onep.InscopixProcessing(session='fc', animal='astro7', data_directory='/Users/suthardr/Desktop/')
# astro_7.read_inscopix()
#
# astro_8 = onep.InscopixProcessing(session='fc', animal='astro8', data_directory='/Users/suthardr/Desktop/')
# astro_8.read_inscopix()
#
# astro_9 = onep.InscopixProcessing(session='fc', animal='astro9', data_directory='/Users/suthardr/Desktop/')
# astro_9.read_inscopix()
#
# collection2 = onep.dCA1Group(astro_7, astro_8, astro_9)
# collection2.preprocess()

# %%
timestamps = astro_4.Timestamps.to_numpy()[:3303].squeeze()
timestamps
