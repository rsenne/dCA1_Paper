# %%
import CalciumKit
import matplotlib.pyplot as plt
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt

# %%
datafile = r"C:\Users\ryansenne\Downloads\wheel_tracking_data_093025_HAB_501N.mat"
datafile = io.loadmat(datafile)

delta_dt = np.median(np.diff(datafile["rotaryTimes"]))
degrees = datafile["rotaryData"]

# %%
meters = CalciumKit.convert_degrees_to_positions(degrees).squeeze()
means, covs = CalciumKit.wheel_kinematics(meters, delta_dt)

# %%
dir(CalciumKit)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'behavior',
#  'convert_degrees_to_positions',
#  'kalman',
#  'kalman_filter_smoother',
#  'wheel_kinematics']

# %%
means
# Out:
# Array([[ 7.4308053e-05, -3.3257505e-01,  8.1749016e+01],
#        [ 2.8382639e-05, -2.9737824e-01,  7.6729996e+01],
#        [ 1.5650818e-05, -2.6438782e-01,  7.1603615e+01],
#        ...,
#        [ 1.3094454e+00, -8.0393534e-03, -3.8185158e-01],
#        [ 1.3094422e+00, -8.1838127e-03, -3.9062980e-01],
#        [ 1.3094436e+00, -8.3603961e-03, -4.4047311e-01]], dtype=float32)

# %%
plt.plot(means[:, 0])

# %%
plt.plot(means[1:20000, 1])

# %%
plt.plot(means[1:20000, 2])
