# %%
from onep import paths
#Cxt A vs B number of events - revision
import pandas as pd
# Load your exported CSV
df = pd.read_csv(paths.processed("figure3", "Num_Detected_Events.csv"))
df
# Out:
#    Context  Num_Events     Mouse
# 0     CxtA           2  astroF10
# 1     CxtA           3   astroF3
# 2     CxtA           3   astroF5
# 3     CxtA           2   astroF6
# 4     CxtA           2   astroF7
# 5     CxtA           4   astroF9
# 6     CxtA           6  astroM10
# 7     CxtA           4   astroM3
# 8     CxtA           3   astroM4
# 9     CxtA           2   astroM5
# 10    CxtA           2   astroM9
# 11    CxtB           1  astroF10
# 12    CxtB           3   astroF3
# 13    CxtB           1   astroF5
# 14    CxtB           1   astroF6
# 15    CxtB           2   astroF7
# 16    CxtB           5   astroF9
# 17    CxtB           4  astroM10
# 18    CxtB           3   astroM6
# 19    CxtB           4   astroM7
# 20    CxtB           3   astroM8

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_num_events_box(df, title="", save_path=None):
    sns.set(style="ticks", font="Arial")
    plt.rcParams.update({
        'font.size': 8,
        'svg.fonttype': 'none'   # <-- keep text editable in SVG
    })

    fig, ax = plt.subplots(figsize=(1.5, 2), dpi=600)

    palette = {
        'CxtA': '#66C1A6',  # teal
        'CxtB': 'black'     # black
    }

    sns.boxplot(
        x='Context', y='Num_Events', data=df,
        width=0.5,
        showcaps=True,
        boxprops=dict(alpha=0.7),
        medianprops={'color': 'white', 'linewidth': 1},
        whiskerprops={'linewidth': 1, 'color': 'black'},
        capprops={'linewidth': 1, 'color': 'black'},
        fliersize=0,
        palette=palette,
        ax=ax
    )

    sns.stripplot(
        x='Context', y='Num_Events', data=df,
        jitter=True,
        linewidth=0.3,
        edgecolor='white',
        palette=palette,
        size=3,
        ax=ax
    )

    ax.legend_.remove() if ax.legend_ else None
    ax.set_ylabel('# Detected Events', fontsize=10)
    ax.set_xlabel('', fontsize=10)
    ax.tick_params(labelsize=8)
    ax.set_ylim(0, 10)
    ax.set_title(title, fontsize=10, pad=10)
    sns.despine()
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=600, bbox_inches='tight', format='svg')

    plt.show()
    return fig, ax

plot_num_events_box(df, save_path=paths.figure_path("figure3", "num_events_Fig3.svg"))
# Out:
# C:\Users\ryansenne\AppData\Local\Temp\ipykernel_41828\724216991.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\ryansenne\AppData\Local\Temp\ipykernel_41828\724216991.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(
# C:\Users\ryansenne\AppData\Local\Temp\ipykernel_41828\724216991.py:53: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# (<Figure size 900x1200 with 1 Axes>, <Axes: ylabel='# Detected Events'>)

# %%
df
# Out:
#    Context  Num_Events     Mouse
# 0     CxtA           2  astroF10
# 1     CxtA           3   astroF3
# 2     CxtA           3   astroF5
# 3     CxtA           2   astroF6
# 4     CxtA           2   astroF7
# 5     CxtA           4   astroF9
# 6     CxtA           6  astroM10
# 7     CxtA           4   astroM3
# 8     CxtA           3   astroM4
# 9     CxtA           2   astroM5
# 10    CxtA           2   astroM9
# 11    CxtB           1  astroF10
# 12    CxtB           3   astroF3
# 13    CxtB           1   astroF5
# 14    CxtB           1   astroF6
# 15    CxtB           2   astroF7
# 16    CxtB           5   astroF9
# 17    CxtB           4  astroM10
# 18    CxtB           3   astroM6
# 19    CxtB           4   astroM7
# 20    CxtB           3   astroM8

# %%
import statsmodels.formula.api as smf

model = smf.mixedlm("Num_Events ~ Context", data=df, groups=df["Mouse"])
result = model.fit()

print(result.summary())
# Out:
#           Mixed Linear Model Regression Results
# ...
# Model:              MixedLM Dependent Variable: Num_Events
# No. Observations:   21      Method:             REML
# No. Groups:         14      Scale:              0.5745
# Min. group size:    1       Log-Likelihood:     -32.4948
# Max. group size:    2       Converged:          Yes
# Mean group size:    1.5
# ----------------------------------------------------------
#                 Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------
# Intercept        3.131    0.376  8.330 0.000  2.395  3.868
# Context[T.CxtB] -0.532    0.385 -1.382 0.167 -1.286  0.222
# Group Var        1.101    1.250
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

df["Sex"] = df["Mouse"].astype(str).str.extract(r'([FM])', expand=False)

sns.set(style="ticks", font="Arial")
plt.rcParams.update({
    'font.size': 8,
    'svg.fonttype': 'none'
})

context_order = sorted(df["Context"].unique())  #
sex_order = ["F", "M"]

sex_palette = {
    "F": "#e377c2",
    "M": "#1f77b4"
}

fig, ax = plt.subplots(figsize=(2, 2.5), dpi=600)

#   BOX PLOT (GROUPED)
sns.boxplot(
    data=df,
    x="Context",
    y="Num_Events",
    hue="Sex",
    order=context_order,
    hue_order=sex_order,
    palette=sex_palette,
    width=0.5,
    fliersize=0,
    linewidth=0.8,
    boxprops=dict(alpha=0.7),
    ax=ax
)

#  STRIP PLOT ON TOP
sns.stripplot(
    data=df,
    x="Context",
    y="Num_Events",
    hue="Sex",
    order=context_order,
    hue_order=sex_order,
    palette=sex_palette,
    jitter=True,
    size=3,
    edgecolor="white",
    linewidth=0.3,
    ax=ax
)

# Remove duplicate legends from box + strip
handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles[:2], labels[:2],
    fontsize=8,
    title="Sex",
    title_fontsize=8,
    loc="upper right",
    frameon=False
)

#  AXIS FORMATTING
ax.set_ylabel("# Detected Events", fontsize=10)
ax.set_xlabel("", fontsize=10)
ax.tick_params(labelsize=8)
ax.set_ylim(0, 8)
sns.despine()
plt.tight_layout()

plt.savefig(
    paths.figure_path("figure3", "num_events_Fig3_sex_context_boxplot.svg"),
    dpi=600,
    bbox_inches='tight',
    format='svg'
)

plt.show()
# Out:
# C:\Users\ryansenne\AppData\Local\Temp\ipykernel_41828\1908055500.py:82: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

# make sure Context + Sex are categorical
df["Context"] = df["Context"].astype("category")
df["Sex"] = df["Sex"].astype("category")

model = smf.ols("Num_Events ~ Context * Sex", data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(model.summary())
print("\nANOVA Table:")
print(anova_table)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Num_Events   R-squared:                       0.179
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1.239
# Date:                Tue, 28 Jul 2026   Prob (F-statistic):              0.326
# Time:                        16:42:55   Log-Likelihood:                -32.955
# No. Observations:                  21   AIC:                             73.91
# Df Residuals:                      17   BIC:                             78.09
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    2.6667      0.527      5.057      0.000       1.554       3.779
# ...
