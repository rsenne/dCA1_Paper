# %%
import pandas as pd
from onep import cell_registration,onephoton

# %%
df_a = pd.read_pickle('/Users/amonast/Desktop/dCA1_astro/Analysis/UMAP_df/umap_recall_cxta.pkl')
df_b = pd.read_pickle('/Users/amonast/Desktop/dCA1_astro/Analysis/UMAP_df/umap_recall_cxtb.pkl')

# %%
df_a
# Out:
#             x          y                                           waveform  \
# 0    1.271606   8.614147  [28.373113350311044, 22.188745947559642, 19.57...
# 1    1.417024   9.097243  [23.61738279116294, 15.924706423943988, 12.721...
# 2    0.545146   8.495040  [1.0625703490573108, 1.0229136207888203, 1.124...
# 3    1.710274  10.490944  [10.078734417369322, 7.004426378305825, 6.1431...
# 4    1.433155   9.124829  [9.881784828250693, 6.759878764511103, 5.75524...
# ..        ...        ...                                                ...
# 203  1.276851   8.036439  [-0.31212235284669176, 0.5325565545497606, 0.2...
# 204  1.317952   7.147206  [4.481363552307068, 2.194481782229367, 1.58725...
# 205  3.853114  11.005047  [2.4831513389026356, 2.974110183111802, 2.4151...
# 206  1.547086   7.638147  [6.338179895244831, 3.6531549746573266, 2.5594...
# 207  1.057689   8.273259  [10.290896175655101, 7.241688341348362, 6.4346...
#
#      cluster_id                     cluster_color
# ...
