# %%
import onep
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import scipy.stats
# %matplotlib inline

# %%
astroM3 = onep.InscopixProcessing(session='A', animal='astroM3', data_directory='/Users/suthardr/Desktop/')

astroM4 = onep.InscopixProcessing(session='A', animal='astroM4', data_directory='/Users/suthardr/Desktop/')

astroM5 = onep.InscopixProcessing(session='A', animal='astroM5', data_directory='/Users/suthardr/Desktop/')

astroM6 = onep.InscopixProcessing(session='A', animal='astroM6', data_directory='/Users/suthardr/Desktop/')

astroF6 = onep.InscopixProcessing(session='A', animal='astroF6', data_directory='/Users/suthardr/Desktop/')

astroM10 = onep.InscopixProcessing(session='A', animal='astroM10', data_directory='/Users/suthardr/Desktop/')

collection = onep.dCA1Group(astroM3, astroM4, astroM5, astroM6, astroF6, astroM10)
collection.preprocess()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 astroM3 = onep.InscopixProcessing(session='A', animal='astroM3', data_directory='/Users/suthardr/Desktop/')
#       3 astroM4 = onep.InscopixProcessing(session='A', animal='astroM4', data_directory='/Users/suthardr/Desktop/')
#       5 astroM5 = onep.InscopixProcessing(session='A', animal='astroM5', data_directory='/Users/suthardr/Desktop/')
#
# AttributeError: module 'onep' has no attribute 'InscopixProcessing'

# %%
astroM7 = onep.InscopixProcessing(session='B', animal='astroM7', data_directory='/Users/suthardr/Desktop/')

astroM8 = onep.InscopixProcessing(session='B', animal='astroM8', data_directory='/Users/suthardr/Desktop/')

astroM9 = onep.InscopixProcessing(session='B', animal='astroM9', data_directory='/Users/suthardr/Desktop/')

astroF3 = onep.InscopixProcessing(session='B', animal='astroF3', data_directory='/Users/suthardr/Desktop/')

astroF5 = onep.InscopixProcessing(session='B', animal='astroF5', data_directory='/Users/suthardr/Desktop/')

astroF8 = onep.InscopixProcessing(session='B', animal='astroF8', data_directory='/Users/suthardr/Desktop/')

astroF9 = onep.InscopixProcessing(session='B', animal='astroF9', data_directory='/Users/suthardr/Desktop/')

astroF10 = onep.InscopixProcessing(session='B', animal='astroF10', data_directory='/Users/suthardr/Desktop/')

astroF11 = onep.InscopixProcessing(session='B', animal='astroF11', data_directory='/Users/suthardr/Desktop/')

collection = onep.dCA1Group(
collection.preprocess()

# %%
import pickle

# Specify the file path to save the pickle
pickle_filepath = '/Users/suthardr/Desktop/collection_cxta_ext1.pkl'  # Change this to your desired path

# Pickle the collection
with open(pickle_filepath, 'wb') as file:
    pickle.dump(collection, file)

print(f'Collection has been pickled and saved to {pickle_filepath}')
# Out:
# Collection has been pickled and saved to /Users/suthardr/Desktop/collection_cxta_ext1.pkl

# %%
astro_7 = onep.InscopixProcessing(session='fc', animal='astro7', data_directory='/Users/suthardr/Desktop/')
astro_7.read_inscopix()

astro_8 = onep.InscopixProcessing(session='fc', animal='astro8', data_directory='/Users/suthardr/Desktop/')
astro_8.read_inscopix()

astro_9 = onep.InscopixProcessing(session='fc', animal='astro9', data_directory='/Users/suthardr/Desktop/')
astro_9.read_inscopix()

collection2 = onep.dCA1Group(astro_7, astro_8, astro_9)
collection2.preprocess()

# %%
timestamps = astro_4.Timestamps.to_numpy()[:3303].squeeze()
timestamps
