# %%
import onep
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import scipy.stats
# %matplotlib inline

# %%
# Load the pickle file
import pickle
with open('/Users/suthardr/Desktop/collection_cxta_ext1.pkl', 'rb') as file:
    collection_cxta_fc = pickle.load(file)

# %%
#Grab the data you want from pickled files
import pickle

# Load the pickle file
with open('/Users/suthardr/Desktop/collection_cxta_fc.pkl', 'rb') as file:
    collection_cxta_fc = pickle.load(file)

with open('/Users/suthardr/Desktop/collection_cxtb_fc.pkl', 'rb') as file:
    collection_cxtb_fc = pickle.load(file)

# %%
def detect_high_activity(df, n_seconds_to_discard, sampling_rate):
    # Discard the first n seconds
    df = df.loc[n_seconds_to_discard:, :]
    idx_offset = n_seconds_to_discard * sampling_rate
    # Sum activity across all cells at each time index
    activity_sum = df.sum(axis=1)
    # Calculate mean and standard deviation
    mean_activity = np.mean(activity_sum)
    std_activity = np.std(activity_sum)
    # Threshold for high activity
    threshold = mean_activity + 1.5 * std_activity
    # Get the indices of the peaks
    idxs = np.where(activity_sum > threshold)[0]
    idxs = idxs + idx_offset
    # Find sequences of 10 or more consecutive indices
    high_activity_periods = []
    consecutive_count = 0
    start_index = None
    for i in range(1, len(idxs)):
        # Check if current index is consecutive to the previous one
        if idxs[i] == idxs[i - 1] + 1:
            consecutive_count += 1
            if consecutive_count == 1:
                start_index = idxs[i - 1]
            if consecutive_count >= 10:
                if start_index is not None and start_index not in high_activity_periods:
                    high_activity_periods.append(start_index)
        else:
            consecutive_count = 0
            start_index = None
    return high_activity_periods, activity_sum

# %%
#Actually detect the areas of high activity
times, activity_sum = detect_high_activity(collection_cxta_fc.animals['astro4'].accepted_traces, 15, 10)

#Tell me the timestamps where these events happen
collection_cxta_fc.animals['astro4'].Timestamps[times]

# %%
#Plot entire session for one mouse with overlaid freezing and detected sequences
plt.plot(collection_cxta_fc.animals['astro3'].accepted_traces.sum(axis=1).to_numpy(), label='Summed dF/F')
plt.plot(collection_cxta_fc.animals['astro3'].freeze_vector, label='Freeze Vector', color='gray')

#astro4 EXTINCTION

plt.axvline(x=324, color='black', linestyle='--')
plt.axvline(x=821, color='black', linestyle='--')
plt.axvline(x=1311, color='black', linestyle='--')
plt.axvline(x=2551, color='black', linestyle='--')
plt.axvline(x=4902, color='black', linestyle='--')
plt.axvline(x=5991, color='black', linestyle='--')
plt.axvline(x=6742, color='black', linestyle='--')
plt.axvline(x=7367, color='black', linestyle='--')
#astro3 1.5
# plt.axvline(x=719, color='black', linestyle='--')
# plt.axvline(x=2249, color='black', linestyle='--')
# plt.axvline(x=2667, color='black', linestyle='--')
# plt.axvline(x=3115, color='black', linestyle='--')

#astro4 1.5
# plt.axvline(x=1215, color='black', linestyle='--')
# plt.axvline(x=1714, color='black', linestyle='--')
# plt.axvline(x=2439, color='black', linestyle='--')
# plt.axvline(x=2854, color='black', linestyle='--')

#astro5 1.5
# plt.axvline(x=346, color='black', linestyle='--')
# plt.axvline(x=898, color='black', linestyle='--')
# plt.axvline(x=1738, color='black', linestyle='--')

#astro6 1.5
# plt.axvline(x=847, color='black', linestyle='--')
# plt.axvline(x=1482, color='black', linestyle='--')
# plt.axvline(x=1749, color='black', linestyle='--')
# plt.axvline(x=2666, color='black', linestyle='--')
# plt.axvline(x=3460, color='black', linestyle='--')
# plt.axvline(x=3538, color='black', linestyle='--')

#astro4 lower threshold events
# plt.axvline(x=363, color='black', linestyle='--')
# plt.axvline(x=1206, color='black', linestyle='--')
# plt.axvline(x=1707, color='black', linestyle='--')
# plt.axvline(x=2112, color='black', linestyle='--')
# plt.axvline(x=2431, color='black', linestyle='--')
# plt.axvline(x=2843, color='black', linestyle='--')

#astro5 lower threshold events
# plt.axvline(x=341, color='black', linestyle='--')
# plt.axvline(x=884, color='black', linestyle='--')
# plt.axvline(x=1730, color='black', linestyle='--')

#astro6 lower threshold events
# plt.axvline(x=494, color='black', linestyle='--')
# plt.axvline(x=841, color='black', linestyle='--')
# plt.axvline(x=1464, color='black', linestyle='--')
# plt.axvline(x=1567, color='black', linestyle='--')
# plt.axvline(x=1745, color='black', linestyle='--')
# plt.axvline(x=2647, color='black', linestyle='--')
# plt.axvline(x=3459, color='black', linestyle='--')
# plt.axvline(x=3522, color='black', linestyle='--')

#astro7 lower threshold events
# plt.axvline(x=398, color='black', linestyle='--')
# plt.axvline(x=1180, color='black', linestyle='--')
# plt.axvline(x=2275, color='black', linestyle='--')
# plt.axvline(x=2657, color='black', linestyle='--')
# plt.axvline(x=3226, color='black', linestyle='--')


#astro8 lower event threshold
# plt.axvline(x=149, color='black', linestyle='--')
# plt.axvline(x=910, color='black', linestyle='--')
# plt.axvline(x=941, color='black', linestyle='--')
# plt.axvline(x=1305, color='black', linestyle='--')
# plt.axvline(x=1320, color='black', linestyle='--')
# plt.axvline(x=1384, color='black', linestyle='--')
# plt.axvline(x=1811, color='black', linestyle='--')
# plt.axvline(x=2465, color='black', linestyle='--')
# plt.axvline(x=2487, color='black', linestyle='--')
# plt.axvline(x=2546, color='black', linestyle='--')
# plt.axvline(x=2752, color='black', linestyle='--')
# plt.axvline(x=2829, color='black', linestyle='--')

#astro8 higher event threshold
# plt.axvline(x=916, color='black', linestyle='--')
# plt.axvline(x=988, color='black', linestyle='--')
# plt.axvline(x=1422, color='black', linestyle='--')
# plt.axvline(x=2759, color='black', linestyle='--')

#astro9 lower event threshold
# plt.axvline(x=675, color='black', linestyle='--')
# plt.axvline(x=1115, color='black', linestyle='--')
# plt.axvline(x=1430, color='black', linestyle='--')


# Customize axes
#plt.ylim(0, astro_3.accepted_traces.sum(axis=1).max() * 1.1)  # Set y-axis limits

# Set labels and title
plt.title('Astro3 EXT1 w Freezing')
plt.xlabel('Time (Indices)')
plt.ylabel('Summed dF/F (AU)')
plt.grid(False)

# # Save the figure
# plt.savefig('/Users/suthardr/Desktop/Astro4_recall_sequences_freezing_threshold1.5.png')

# Show the plot
plt.show()

# %%
#Plot the ETAs for detected sequences
across_eta_, time = onep.eta_individual_cells(
    data=stats.zscore(collection_cxta_fc.animals['astro3'].accepted_traces.to_numpy()[:3303,:].T, axis=1),
    timestamps=collection_cxta_fc.animals['astro3'].Timestamps[:3303,].to_numpy().squeeze(),
    events=[[32.475075587076,  82.1369604079276,  131.199305371787,
       255.1042091501693, 490.2237564005995, 599.1401637541776,
       674.2824924971965, 736.7345609338811],], #actually onsets
    window=15
)

# %%
def sequence_heat_plot(unsorted_array, time, ax=None):
    """
    arr: N x T array of cell activity
    time: T array of time
    returns: ax
    """
    # z-score array
    arr = stats.zscore(unsorted_array, axis=1)
    # sort array based on argmax of each row
    arr, _ = onep.maxsort(arr)
    # make a figure
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    # plot the heatmap
    sns.heatmap(arr, cmap='mako',cbar=True, cbar_kws={"label": r"z-scored $\frac{dF}{F}$"})
    # set x-ticks
    ax.set_xticks(np.linspace(0, arr.shape[1], 5), np.linspace(np.min(time), np.max(time), 5))
    # ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
    ax.axvline((time.shape[0]/3), linestyle='--', color='white')
    # set labels
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Cells')
    plt.tight_layout()
    return ax, fig
