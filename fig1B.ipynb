# %%
from onep import *
import holoviews as hv
import matplotlib.pyplot as plt
import numpy as np
import panel as pn
hv.extension('bokeh')
import tifffile
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
astro = cell_registration.CellReg('astro8','FOV1',2)
image_files = astro.get_summary_images(image_type='max dff',shifted=False)
images = [tifffile.imread(f) for f in image_files]
# Out:
# ['/Users/suthardr/Desktop/Cell_Traces/Summary_Images/astro8_FOV1/DFF/astro8_fc_maxdff.tiff', '/Users/suthardr/Desktop/Cell_Traces/Summary_Images/astro8_FOV1/DFF/astro8_gen1_maxdff.tiff']

# %%
footprints=astro.load_footprints_3D(affine_shifted=False)
# Out:
# Make sure these are in order:
# ['fc' 'gen1' 'gen2' 'gen3' 'gen4']
# If theyre not in order, run load_footprints_3D again and set select sessions to True to put them in order
# ['/Users/suthardr/Desktop/Cell_Traces/CellReg/astro8_FOV1/converted_maps/astro8_fc_converted.mat', '/Users/suthardr/Desktop/Cell_Traces/CellReg/astro8_FOV1/converted_maps/astro8_gen1_converted.mat']

# %%
plots=[astro.rois_plot(session_ind = i,image=images[i]) for i in range(astro.N_sessions)]

# %%
plots[0]
# Out:
# :Overlay
#    .Image.I  :Image   [x,y]   (z)
#    .Image.II :Image   [x,y]   (z)

# %%
hv.save(plots[0],r"C:\Users\RamirezLab\Desktop\Rebecca\Figures\astro5_FC_overlay_allcells.png")
