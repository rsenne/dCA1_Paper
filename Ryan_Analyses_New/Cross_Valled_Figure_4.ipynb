# %%
import sys
sys.path.append('C:/Users/ryansenne/PycharmProjects/dCA1_Paper')

import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
# %matplotlib inline

# %%
#Load pickles for FC and CxtA
with open(r'\Users\ryansenne\Desktop\Dill\collection_cxta_allmice.pkl', 'rb') as file:
    collection_cxta = pickle.load(file)

with open(r'\Users\ryansenne\Desktop\Dill\collection_cxtb_allmice.pkl', 'rb') as file:
    collection_cxtb = pickle.load(file)

with open(r'\Users\ryansenne\Desktop\Dill\collection_fc_allmice.pkl', 'rb') as file:
    collection_fc = pickle.load(file)

# %%
collection_fc.animals['astroF8'].accepted_traces
# Out:
#                 C000      C001      C002      C003      C004      C005  \
# 0.000000    0.001433  0.000201  0.000294  0.019031 -0.000421  0.005958
# 0.099922    0.002470  0.001236 -0.000456  0.017175  0.000232  0.004651
# 0.199844    0.001775  0.002186 -0.001198  0.016479  0.000578  0.003421
# 0.299766    0.000487  0.001480 -0.000443  0.016435  0.003258  0.003589
# 0.399688    0.000071  0.001653 -0.000254  0.016391  0.006353  0.004425
# ...              ...       ...       ...       ...       ...       ...
# 359.419036  0.001598  0.001050  0.000503  0.003714  0.002474  0.001668
# 359.518957  0.000360  0.000619  0.000860  0.004852  0.002093  0.000648
# 359.618879  0.000573  0.000261  0.001283  0.004116  0.001847  0.000642
# 359.718801  0.001523  0.000159  0.000543  0.003752  0.001949  0.001034
# 359.818723  0.001342  0.000297  0.000678  0.003328  0.000342  0.001714
#
#                 C006      C007      C008      C009  ...      C314      C315  \
# ...

# %%
collection_cxta.animals['astroF8'].accepted_traces
# Out:
#                 C000      C001      C002      C003      C004      C005  \
# 0.000000   -0.005059  0.005928  0.014236  0.015417  0.002979  0.024930
# 0.099922   -0.004222  0.005984  0.010169  0.013836  0.001269  0.017562
# 0.199844   -0.001834  0.004882  0.008929  0.010711  0.000696  0.017003
# 0.299766   -0.001426  0.005022  0.008234  0.008454  0.000691  0.013527
# 0.399688   -0.002417  0.005873  0.008308  0.009729  0.002032  0.014588
# ...              ...       ...       ...       ...       ...       ...
# 359.518909 -0.000857  0.015815  0.006058  0.002435  0.001696  0.000338
# 359.618830 -0.000290  0.016303  0.007279  0.002940  0.001802 -0.000384
# 359.718752 -0.001941  0.016299  0.008251  0.002703  0.001905  0.000404
# 359.818674 -0.001231  0.016876  0.010147  0.001273  0.000949  0.000354
# 359.918596 -0.000645  0.015198  0.009997 -0.000540  0.001810  0.001239
#
#                 C006      C007      C008      C009  ...      C281      C282  \
# ...
